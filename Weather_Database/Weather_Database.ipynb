# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
## Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    ## Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    ## If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

## Print the city count to confirm sufficient count
len(cities)
# Out:
# 759

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

## Create Import key path to avoid saving api key in sub-folder. 
import sys
sys.path.insert(0,'..')

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
## Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []
# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        ## Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]  
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"] 
        city_weather_descrpt = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]      
       
        ## Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_descrpt,
                          "Country": city_country})
                          
                                      
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ruidoso
# Processing Record 2 of Set 1 | kahului
# Processing Record 3 of Set 1 | funtua
# Processing Record 4 of Set 1 | shingu
# Processing Record 5 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 6 of Set 1 | lebu
# Processing Record 7 of Set 1 | aktash
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | vila velha
# Processing Record 11 of Set 1 | ribeira grande
# Processing Record 12 of Set 1 | buraydah
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | esperance
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | bure
# Processing Record 19 of Set 1 | olafsvik
# Processing Record 20 of Set 1 | hermanus
# Processing Record 21 of Set 1 | bredasdorp
# Processing Record 22 of Set 1 | dutlwe
# Processing Record 23 of Set 1 | kununurra
# Processing Record 24 of Set 1 | kysyl-syr
# Processing Record 25 of Set 1 | airai
# Processing Record 26 of Set 1 | new norfolk
# Processing Record 27 of Set 1 | dikson
# Processing Record 28 of Set 1 | hobart
# Processing Record 29 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 32 of Set 1 | cape town
# Processing Record 33 of Set 1 | puerto del rosario
# Processing Record 34 of Set 1 | la ronge
# Processing Record 35 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 1 | atuona
# Processing Record 37 of Set 1 | maldonado
# Processing Record 38 of Set 1 | coachella
# Processing Record 39 of Set 1 | marovoay
# Processing Record 40 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 41 of Set 1 | vostok
# Processing Record 42 of Set 1 | talnakh
# Processing Record 43 of Set 1 | arys
# Processing Record 44 of Set 1 | berdigestyakh
# Processing Record 45 of Set 1 | nanortalik
# Processing Record 46 of Set 1 | provideniya
# Processing Record 47 of Set 1 | guerrero negro
# Processing Record 48 of Set 1 | marquette
# Processing Record 49 of Set 1 | saldanha
# Processing Record 50 of Set 1 | avera
# Processing Record 1 of Set 2 | siderno
# Processing Record 2 of Set 2 | saint-philippe
# Processing Record 3 of Set 2 | pryamitsyno
# Processing Record 4 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 5 of Set 2 | maur
# Processing Record 6 of Set 2 | meulaboh
# Processing Record 7 of Set 2 | hithadhoo
# Processing Record 8 of Set 2 | dingle
# Processing Record 9 of Set 2 | pisco
# Processing Record 10 of Set 2 | bluff
# Processing Record 11 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 2 | ancud
# Processing Record 13 of Set 2 | pangai
# Processing Record 14 of Set 2 | mindelo
# Processing Record 15 of Set 2 | guanica
# Processing Record 16 of Set 2 | ayagoz
# Processing Record 17 of Set 2 | kjollefjord
# Processing Record 18 of Set 2 | khatanga
# Processing Record 19 of Set 2 | tamandare
# Processing Record 20 of Set 2 | xihe
# Processing Record 21 of Set 2 | gangotri
# City not found. Skipping...
# Processing Record 22 of Set 2 | vaini
# Processing Record 23 of Set 2 | yumen
# Processing Record 24 of Set 2 | halifax
# Processing Record 25 of Set 2 | mahebourg
# Processing Record 26 of Set 2 | mazagao
# Processing Record 27 of Set 2 | honiara
# Processing Record 28 of Set 2 | huilong
# Processing Record 29 of Set 2 | magadan
# Processing Record 30 of Set 2 | yellowknife
# Processing Record 31 of Set 2 | hasaki
# Processing Record 32 of Set 2 | takoradi
# Processing Record 33 of Set 2 | svetlyy
# Processing Record 34 of Set 2 | hambantota
# Processing Record 35 of Set 2 | geraldton
# Processing Record 36 of Set 2 | san patricio
# Processing Record 37 of Set 2 | archidona
# Processing Record 38 of Set 2 | altay
# Processing Record 39 of Set 2 | georgetown
# Processing Record 40 of Set 2 | east london
# Processing Record 41 of Set 2 | aksu
# Processing Record 42 of Set 2 | tuktoyaktuk
# Processing Record 43 of Set 2 | chimore
# Processing Record 44 of Set 2 | nazret
# Processing Record 45 of Set 2 | port alfred
# Processing Record 46 of Set 2 | constantine
# Processing Record 47 of Set 2 | iqaluit
# Processing Record 48 of Set 2 | disna
# Processing Record 49 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 2 | castro
# Processing Record 1 of Set 3 | selikhino
# Processing Record 2 of Set 3 | baglung
# Processing Record 3 of Set 3 | corner brook
# Processing Record 4 of Set 3 | ahipara
# Processing Record 5 of Set 3 | san jose
# Processing Record 6 of Set 3 | barrow
# Processing Record 7 of Set 3 | ponta do sol
# Processing Record 8 of Set 3 | san rafael
# Processing Record 9 of Set 3 | tuatapere
# Processing Record 10 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 3 | kudahuvadhoo
# Processing Record 12 of Set 3 | chokurdakh
# Processing Record 13 of Set 3 | cabo san lucas
# Processing Record 14 of Set 3 | vardo
# Processing Record 15 of Set 3 | tiksi
# Processing Record 16 of Set 3 | salina
# Processing Record 17 of Set 3 | padang
# Processing Record 18 of Set 3 | torbay
# Processing Record 19 of Set 3 | arraial do cabo
# Processing Record 20 of Set 3 | venezuela
# Processing Record 21 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 3 | fort nelson
# Processing Record 23 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 3 | fort-shevchenko
# Processing Record 25 of Set 3 | port elizabeth
# Processing Record 26 of Set 3 | warrington
# Processing Record 27 of Set 3 | iquitos
# Processing Record 28 of Set 3 | coulihaut
# City not found. Skipping...
# Processing Record 29 of Set 3 | hilo
# Processing Record 30 of Set 3 | leningradskiy
# Processing Record 31 of Set 3 | manakara
# Processing Record 32 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 3 | hongjiang
# Processing Record 34 of Set 3 | puerto ayora
# Processing Record 35 of Set 3 | luderitz
# Processing Record 36 of Set 3 | mehran
# Processing Record 37 of Set 3 | tura
# Processing Record 38 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 3 | matay
# Processing Record 40 of Set 3 | mataura
# Processing Record 41 of Set 3 | brewster
# Processing Record 42 of Set 3 | chuy
# Processing Record 43 of Set 3 | severo-kurilsk
# Processing Record 44 of Set 3 | ormara
# Processing Record 45 of Set 3 | richards bay
# Processing Record 46 of Set 3 | wuda
# Processing Record 47 of Set 3 | dudinka
# Processing Record 48 of Set 3 | cherskiy
# Processing Record 49 of Set 3 | lorengau
# Processing Record 50 of Set 3 | darhan
# Processing Record 1 of Set 4 | coquimbo
# Processing Record 2 of Set 4 | kapoeta
# Processing Record 3 of Set 4 | alice springs
# Processing Record 4 of Set 4 | yuncheng
# Processing Record 5 of Set 4 | bambous virieux
# Processing Record 6 of Set 4 | kruisfontein
# Processing Record 7 of Set 4 | avarua
# Processing Record 8 of Set 4 | abu samrah
# Processing Record 9 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 4 | shkotovo-22
# City not found. Skipping...
# Processing Record 11 of Set 4 | svetlogorsk
# Processing Record 12 of Set 4 | pandan
# Processing Record 13 of Set 4 | portland
# Processing Record 14 of Set 4 | sioux lookout
# Processing Record 15 of Set 4 | bethel
# Processing Record 16 of Set 4 | faanui
# Processing Record 17 of Set 4 | qaanaaq
# Processing Record 18 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 4 | necochea
# Processing Record 20 of Set 4 | dinghai
# Processing Record 21 of Set 4 | polunochnoye
# Processing Record 22 of Set 4 | mercedes
# Processing Record 23 of Set 4 | porto belo
# Processing Record 24 of Set 4 | burkhala
# City not found. Skipping...
# Processing Record 25 of Set 4 | xuzhou
# Processing Record 26 of Set 4 | manta
# Processing Record 27 of Set 4 | pevek
# Processing Record 28 of Set 4 | kaitangata
# Processing Record 29 of Set 4 | inta
# Processing Record 30 of Set 4 | mafinga
# Processing Record 31 of Set 4 | usinsk
# Processing Record 32 of Set 4 | muros
# Processing Record 33 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 34 of Set 4 | peace river
# Processing Record 35 of Set 4 | caravelas
# Processing Record 36 of Set 4 | sfantu gheorghe
# Processing Record 37 of Set 4 | kargil
# Processing Record 38 of Set 4 | komsomolskoye
# Processing Record 39 of Set 4 | kavieng
# Processing Record 40 of Set 4 | shelburne
# Processing Record 41 of Set 4 | wapakoneta
# Processing Record 42 of Set 4 | marrakesh
# Processing Record 43 of Set 4 | maniitsoq
# Processing Record 44 of Set 4 | lima
# Processing Record 45 of Set 4 | ambon
# Processing Record 46 of Set 4 | howell
# Processing Record 47 of Set 4 | sao filipe
# Processing Record 48 of Set 4 | baruun-urt
# Processing Record 49 of Set 4 | diego de almagro
# Processing Record 50 of Set 4 | dapaong
# Processing Record 1 of Set 5 | chara
# Processing Record 2 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 5 | constitucion
# Processing Record 4 of Set 5 | thompson
# Processing Record 5 of Set 5 | thinadhoo
# Processing Record 6 of Set 5 | rawson
# Processing Record 7 of Set 5 | sandnessjoen
# Processing Record 8 of Set 5 | anadyr
# Processing Record 9 of Set 5 | egvekinot
# Processing Record 10 of Set 5 | huaibei
# Processing Record 11 of Set 5 | bubaque
# Processing Record 12 of Set 5 | san quintin
# Processing Record 13 of Set 5 | kadykchan
# City not found. Skipping...
# Processing Record 14 of Set 5 | moissala
# Processing Record 15 of Set 5 | gushikawa
# Processing Record 16 of Set 5 | majene
# Processing Record 17 of Set 5 | kaiserslautern
# Processing Record 18 of Set 5 | westport
# Processing Record 19 of Set 5 | zaraza
# Processing Record 20 of Set 5 | narsaq
# Processing Record 21 of Set 5 | batagay-alyta
# Processing Record 22 of Set 5 | platanos
# Processing Record 23 of Set 5 | kodiak
# Processing Record 24 of Set 5 | hire
# City not found. Skipping...
# Processing Record 25 of Set 5 | jamestown
# Processing Record 26 of Set 5 | zhigansk
# Processing Record 27 of Set 5 | fortuna
# Processing Record 28 of Set 5 | nikolskoye
# Processing Record 29 of Set 5 | aksarka
# Processing Record 30 of Set 5 | ginda
# Processing Record 31 of Set 5 | pagudpud
# Processing Record 32 of Set 5 | zaozerne
# Processing Record 33 of Set 5 | lompoc
# Processing Record 34 of Set 5 | sao jose da coroa grande
# Processing Record 35 of Set 5 | kargasok
# Processing Record 36 of Set 5 | xining
# Processing Record 37 of Set 5 | ilulissat
# Processing Record 38 of Set 5 | shitanjing
# Processing Record 39 of Set 5 | ilo
# Processing Record 40 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 5 | hailey
# Processing Record 42 of Set 5 | mandera
# Processing Record 43 of Set 5 | gimbi
# Processing Record 44 of Set 5 | manaure
# Processing Record 45 of Set 5 | arman
# Processing Record 46 of Set 5 | kwekwe
# Processing Record 47 of Set 5 | ostrovnoy
# Processing Record 48 of Set 5 | atar
# Processing Record 49 of Set 5 | flin flon
# Processing Record 50 of Set 5 | nuevo progreso
# Processing Record 1 of Set 6 | kollumerland
# City not found. Skipping...
# Processing Record 2 of Set 6 | comodoro rivadavia
# Processing Record 3 of Set 6 | san francisco
# Processing Record 4 of Set 6 | mar del plata
# Processing Record 5 of Set 6 | lumphat
# Processing Record 6 of Set 6 | holiday
# Processing Record 7 of Set 6 | pontianak
# Processing Record 8 of Set 6 | camacha
# Processing Record 9 of Set 6 | byron bay
# Processing Record 10 of Set 6 | tawau
# Processing Record 11 of Set 6 | butaritari
# Processing Record 12 of Set 6 | klaksvik
# Processing Record 13 of Set 6 | upernavik
# Processing Record 14 of Set 6 | marawi
# Processing Record 15 of Set 6 | koshurnikovo
# Processing Record 16 of Set 6 | souillac
# Processing Record 17 of Set 6 | novikovo
# Processing Record 18 of Set 6 | roald
# Processing Record 19 of Set 6 | northam
# Processing Record 20 of Set 6 | nishihara
# Processing Record 21 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 6 | mmathubudukwane
# Processing Record 23 of Set 6 | danielskuil
# Processing Record 24 of Set 6 | hofn
# Processing Record 25 of Set 6 | basco
# Processing Record 26 of Set 6 | tsaratanana
# Processing Record 27 of Set 6 | del rio
# Processing Record 28 of Set 6 | rawah
# Processing Record 29 of Set 6 | lavrentiya
# Processing Record 30 of Set 6 | bambanglipuro
# Processing Record 31 of Set 6 | oktyabrskoye
# Processing Record 32 of Set 6 | sitka
# Processing Record 33 of Set 6 | najran
# Processing Record 34 of Set 6 | mount gambier
# Processing Record 35 of Set 6 | victoria
# Processing Record 36 of Set 6 | morgan city
# Processing Record 37 of Set 6 | jinxiang
# Processing Record 38 of Set 6 | ailigandi
# Processing Record 39 of Set 6 | praia
# Processing Record 40 of Set 6 | koslan
# Processing Record 41 of Set 6 | mangrol
# Processing Record 42 of Set 6 | port hawkesbury
# Processing Record 43 of Set 6 | alekseyevsk
# Processing Record 44 of Set 6 | sao joao da barra
# Processing Record 45 of Set 6 | urusha
# Processing Record 46 of Set 6 | mount forest
# Processing Record 47 of Set 6 | bengkulu
# Processing Record 48 of Set 6 | haapiti
# Processing Record 49 of Set 6 | ushtobe
# Processing Record 50 of Set 6 | vaitape
# Processing Record 1 of Set 7 | havre-saint-pierre
# Processing Record 2 of Set 7 | mehamn
# Processing Record 3 of Set 7 | port maria
# Processing Record 4 of Set 7 | laguna
# Processing Record 5 of Set 7 | salihorsk
# Processing Record 6 of Set 7 | evensk
# Processing Record 7 of Set 7 | itoman
# Processing Record 8 of Set 7 | saint-pierre
# Processing Record 9 of Set 7 | asyut
# Processing Record 10 of Set 7 | pangnirtung
# Processing Record 11 of Set 7 | carnarvon
# Processing Record 12 of Set 7 | mezen
# Processing Record 13 of Set 7 | okhotsk
# Processing Record 14 of Set 7 | euclides da cunha
# Processing Record 15 of Set 7 | kamenka
# Processing Record 16 of Set 7 | manchester
# Processing Record 17 of Set 7 | palasa
# Processing Record 18 of Set 7 | poshekhonye
# Processing Record 19 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 20 of Set 7 | aklavik
# Processing Record 21 of Set 7 | rovaniemi
# Processing Record 22 of Set 7 | inzer
# Processing Record 23 of Set 7 | faya
# Processing Record 24 of Set 7 | matara
# Processing Record 25 of Set 7 | pokhara
# Processing Record 26 of Set 7 | alta floresta
# Processing Record 27 of Set 7 | nelson bay
# Processing Record 28 of Set 7 | millinocket
# Processing Record 29 of Set 7 | yakeshi
# Processing Record 30 of Set 7 | moranbah
# Processing Record 31 of Set 7 | yulara
# Processing Record 32 of Set 7 | guajara-mirim
# City not found. Skipping...
# Processing Record 33 of Set 7 | stornoway
# Processing Record 34 of Set 7 | peniche
# Processing Record 35 of Set 7 | calarasi
# Processing Record 36 of Set 7 | qeshm
# Processing Record 37 of Set 7 | taoudenni
# Processing Record 38 of Set 7 | katsuura
# Processing Record 39 of Set 7 | ust-tsilma
# Processing Record 40 of Set 7 | koungheul
# Processing Record 41 of Set 7 | tilichiki
# Processing Record 42 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 43 of Set 7 | emerald
# Processing Record 44 of Set 7 | cabedelo
# Processing Record 45 of Set 7 | gizo
# Processing Record 46 of Set 7 | tecoanapa
# Processing Record 47 of Set 7 | baft
# Processing Record 48 of Set 7 | kenai
# Processing Record 49 of Set 7 | elko
# Processing Record 50 of Set 7 | kamaishi
# Processing Record 1 of Set 8 | te anau
# Processing Record 2 of Set 8 | lebork
# Processing Record 3 of Set 8 | longyearbyen
# Processing Record 4 of Set 8 | skibbereen
# Processing Record 5 of Set 8 | madingou
# Processing Record 6 of Set 8 | tarancon
# Processing Record 7 of Set 8 | malaryta
# Processing Record 8 of Set 8 | sorland
# Processing Record 9 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 8 | jalu
# Processing Record 11 of Set 8 | deputatskiy
# Processing Record 12 of Set 8 | clifton
# Processing Record 13 of Set 8 | parvatipuram
# Processing Record 14 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 8 | bargarh
# Processing Record 16 of Set 8 | orlovskiy
# Processing Record 17 of Set 8 | langham
# Processing Record 18 of Set 8 | san cristobal
# Processing Record 19 of Set 8 | umm bab
# Processing Record 20 of Set 8 | haines junction
# Processing Record 21 of Set 8 | vancouver
# Processing Record 22 of Set 8 | buchanan
# Processing Record 23 of Set 8 | ulaangom
# Processing Record 24 of Set 8 | ferme-neuve
# Processing Record 25 of Set 8 | anqing
# Processing Record 26 of Set 8 | dien bien
# City not found. Skipping...
# Processing Record 27 of Set 8 | broken hill
# Processing Record 28 of Set 8 | tasiilaq
# Processing Record 29 of Set 8 | arona
# Processing Record 30 of Set 8 | florence
# Processing Record 31 of Set 8 | kindu
# Processing Record 32 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record 33 of Set 8 | skerries
# Processing Record 34 of Set 8 | goderich
# Processing Record 35 of Set 8 | rocha
# Processing Record 36 of Set 8 | cidreira
# Processing Record 37 of Set 8 | kijang
# Processing Record 38 of Set 8 | sur
# Processing Record 39 of Set 8 | snezhnogorsk
# Processing Record 40 of Set 8 | port pirie
# Processing Record 41 of Set 8 | santa cruz
# Processing Record 42 of Set 8 | walvis bay
# Processing Record 43 of Set 8 | pacifica
# Processing Record 44 of Set 8 | shkotovo-26
# City not found. Skipping...
# Processing Record 45 of Set 8 | parry sound
# Processing Record 46 of Set 8 | almiros
# City not found. Skipping...
# Processing Record 47 of Set 8 | mount pleasant
# Processing Record 48 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 49 of Set 8 | blagoyevo
# Processing Record 50 of Set 8 | vyshchetarasivka
# Processing Record 1 of Set 9 | berezovyy
# Processing Record 2 of Set 9 | xiamen
# Processing Record 3 of Set 9 | digby
# Processing Record 4 of Set 9 | qiongshan
# Processing Record 5 of Set 9 | houston
# Processing Record 6 of Set 9 | verkhnevilyuysk
# Processing Record 7 of Set 9 | binzhou
# Processing Record 8 of Set 9 | colares
# Processing Record 9 of Set 9 | norman wells
# Processing Record 10 of Set 9 | okoneshnikovo
# Processing Record 11 of Set 9 | saskylakh
# Processing Record 12 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 9 | aasiaat
# Processing Record 14 of Set 9 | atambua
# Processing Record 15 of Set 9 | malakal
# Processing Record 16 of Set 9 | ardesen
# Processing Record 17 of Set 9 | manzhouli
# Processing Record 18 of Set 9 | marsh harbour
# Processing Record 19 of Set 9 | massaguet
# Processing Record 20 of Set 9 | nyurba
# Processing Record 21 of Set 9 | rogovatoye
# Processing Record 22 of Set 9 | luba
# Processing Record 23 of Set 9 | oriximina
# Processing Record 24 of Set 9 | saint george
# Processing Record 25 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 9 | colborne
# Processing Record 27 of Set 9 | pangkalanbuun
# Processing Record 28 of Set 9 | shibarghan
# City not found. Skipping...
# Processing Record 29 of Set 9 | tabou
# Processing Record 30 of Set 9 | amilly
# Processing Record 31 of Set 9 | taitung
# Processing Record 32 of Set 9 | acarau
# Processing Record 33 of Set 9 | kavaratti
# Processing Record 34 of Set 9 | port hardy
# Processing Record 35 of Set 9 | banda aceh
# Processing Record 36 of Set 9 | karratha
# Processing Record 37 of Set 9 | charters towers
# Processing Record 38 of Set 9 | callaguip
# Processing Record 39 of Set 9 | gwadar
# Processing Record 40 of Set 9 | isangel
# Processing Record 41 of Set 9 | bilibino
# Processing Record 42 of Set 9 | havelock
# Processing Record 43 of Set 9 | buala
# Processing Record 44 of Set 9 | menongue
# Processing Record 45 of Set 9 | patitirion
# Processing Record 46 of Set 9 | mariental
# Processing Record 47 of Set 9 | hailar
# Processing Record 48 of Set 9 | sokoto
# Processing Record 49 of Set 9 | adrar
# Processing Record 50 of Set 9 | mackay
# Processing Record 1 of Set 10 | merauke
# Processing Record 2 of Set 10 | port shepstone
# Processing Record 3 of Set 10 | kupang
# Processing Record 4 of Set 10 | tupiza
# Processing Record 5 of Set 10 | synya
# Processing Record 6 of Set 10 | inderborskiy
# City not found. Skipping...
# Processing Record 7 of Set 10 | victor harbor
# Processing Record 8 of Set 10 | sahrak
# City not found. Skipping...
# Processing Record 9 of Set 10 | clyde river
# Processing Record 10 of Set 10 | vanimo
# Processing Record 11 of Set 10 | nome
# Processing Record 12 of Set 10 | ponta delgada
# Processing Record 13 of Set 10 | tailai
# Processing Record 14 of Set 10 | miraflores
# Processing Record 15 of Set 10 | daugavpils
# Processing Record 16 of Set 10 | touros
# Processing Record 17 of Set 10 | kimbe
# Processing Record 18 of Set 10 | providencia
# Processing Record 19 of Set 10 | lethem
# Processing Record 20 of Set 10 | puerto vallarta
# Processing Record 21 of Set 10 | sabha
# Processing Record 22 of Set 10 | noumea
# Processing Record 23 of Set 10 | ambilobe
# Processing Record 24 of Set 10 | gravdal
# Processing Record 25 of Set 10 | miyazu
# Processing Record 26 of Set 10 | thanh hoa
# Processing Record 27 of Set 10 | ngunguru
# Processing Record 28 of Set 10 | turayf
# Processing Record 29 of Set 10 | lagoa
# Processing Record 30 of Set 10 | nemuro
# Processing Record 31 of Set 10 | mount isa
# Processing Record 32 of Set 10 | gunnedah
# Processing Record 33 of Set 10 | tomatlan
# Processing Record 34 of Set 10 | viernheim
# Processing Record 35 of Set 10 | chincha alta
# Processing Record 36 of Set 10 | geresk
# City not found. Skipping...
# Processing Record 37 of Set 10 | laje
# Processing Record 38 of Set 10 | barra do bugres
# Processing Record 39 of Set 10 | bahia honda
# Processing Record 40 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 41 of Set 10 | atlantic city
# Processing Record 42 of Set 10 | tanjong sepat
# City not found. Skipping...
# Processing Record 43 of Set 10 | ndola
# Processing Record 44 of Set 10 | malartic
# Processing Record 45 of Set 10 | eldikan
# City not found. Skipping...
# Processing Record 46 of Set 10 | dosso
# Processing Record 47 of Set 10 | lamu
# Processing Record 48 of Set 10 | ternate
# Processing Record 49 of Set 10 | senneterre
# Processing Record 50 of Set 10 | atikokan
# Processing Record 1 of Set 11 | kampot
# Processing Record 2 of Set 11 | westlock
# Processing Record 3 of Set 11 | riberalta
# Processing Record 4 of Set 11 | prince george
# Processing Record 5 of Set 11 | port hedland
# Processing Record 6 of Set 11 | vestmanna
# Processing Record 7 of Set 11 | kaman
# Processing Record 8 of Set 11 | barcelona
# Processing Record 9 of Set 11 | vestmannaeyjar
# Processing Record 10 of Set 11 | san juan
# Processing Record 11 of Set 11 | guadix
# Processing Record 12 of Set 11 | mazatlan
# Processing Record 13 of Set 11 | sangar
# Processing Record 14 of Set 11 | dalbandin
# Processing Record 15 of Set 11 | nanakuli
# Processing Record 16 of Set 11 | fairlie
# Processing Record 17 of Set 11 | bethal
# Processing Record 18 of Set 11 | tiassale
# Processing Record 19 of Set 11 | teya
# Processing Record 20 of Set 11 | praya
# Processing Record 21 of Set 11 | parrita
# Processing Record 22 of Set 11 | ukhta
# Processing Record 23 of Set 11 | empangeni
# Processing Record 24 of Set 11 | leshukonskoye
# Processing Record 25 of Set 11 | west bay
# Processing Record 26 of Set 11 | lucapa
# Processing Record 27 of Set 11 | castle douglas
# Processing Record 28 of Set 11 | gat
# Processing Record 29 of Set 11 | ahuimanu
# Processing Record 30 of Set 11 | sao sebastiao
# Processing Record 31 of Set 11 | quatre cocos
# Processing Record 32 of Set 11 | araxa
# Processing Record 33 of Set 11 | dunedin
# Processing Record 34 of Set 11 | awjilah
# Processing Record 35 of Set 11 | berbera
# Processing Record 36 of Set 11 | juniyah
# City not found. Skipping...
# Processing Record 37 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 11 | tankhoy
# Processing Record 39 of Set 11 | tiznit
# Processing Record 40 of Set 11 | linjiang
# Processing Record 41 of Set 11 | atasu
# Processing Record 42 of Set 11 | abha
# Processing Record 43 of Set 11 | raudeberg
# Processing Record 44 of Set 11 | suntar
# Processing Record 45 of Set 11 | arlit
# Processing Record 46 of Set 11 | bushenyi
# Processing Record 47 of Set 11 | chumphon
# Processing Record 48 of Set 11 | galiakot
# Processing Record 49 of Set 11 | san andres
# Processing Record 50 of Set 11 | almonte
# Processing Record 1 of Set 12 | naze
# Processing Record 2 of Set 12 | moree
# Processing Record 3 of Set 12 | tsybli
# Processing Record 4 of Set 12 | along
# Processing Record 5 of Set 12 | waingapu
# Processing Record 6 of Set 12 | babanusah
# City not found. Skipping...
# Processing Record 7 of Set 12 | beringovskiy
# Processing Record 8 of Set 12 | kasempa
# Processing Record 9 of Set 12 | sungai petani
# Processing Record 10 of Set 12 | hami
# Processing Record 11 of Set 12 | redmond
# Processing Record 12 of Set 12 | inirida
# Processing Record 13 of Set 12 | kaya
# Processing Record 14 of Set 12 | shimoda
# Processing Record 15 of Set 12 | fairbanks
# Processing Record 16 of Set 12 | ascension
# Processing Record 17 of Set 12 | qui nhon
# Processing Record 18 of Set 12 | ondjiva
# Processing Record 19 of Set 12 | pierre
# Processing Record 20 of Set 12 | kitui
# Processing Record 21 of Set 12 | auki
# Processing Record 22 of Set 12 | bose
# Processing Record 23 of Set 12 | kongoussi
# Processing Record 24 of Set 12 | birao
# Processing Record 25 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 26 of Set 12 | bud
# Processing Record 27 of Set 12 | campo grande
# Processing Record 28 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 29 of Set 12 | liwale
# Processing Record 30 of Set 12 | almeirim
# Processing Record 31 of Set 12 | north bend
# Processing Record 32 of Set 12 | komsomolskiy
# Processing Record 33 of Set 12 | port lincoln
# Processing Record 34 of Set 12 | salinopolis
# Processing Record 35 of Set 12 | bermeo
# Processing Record 36 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 37 of Set 12 | la paz
# Processing Record 38 of Set 12 | havoysund
# Processing Record 39 of Set 12 | tam ky
# Processing Record 40 of Set 12 | santa maria
# Processing Record 41 of Set 12 | cayenne
# Processing Record 42 of Set 12 | tomiya
# Processing Record 43 of Set 12 | rioja
# Processing Record 44 of Set 12 | nadym
# Processing Record 45 of Set 12 | honningsvag
# Processing Record 46 of Set 12 | rivadavia
# Processing Record 47 of Set 12 | gallup
# Processing Record 48 of Set 12 | zaranj
# Processing Record 49 of Set 12 | aloleng
# Processing Record 50 of Set 12 | maceio
# Processing Record 1 of Set 13 | vuktyl
# Processing Record 2 of Set 13 | beruwala
# Processing Record 3 of Set 13 | codrington
# Processing Record 4 of Set 13 | port blair
# Processing Record 5 of Set 13 | cam ranh
# Processing Record 6 of Set 13 | forset
# City not found. Skipping...
# Processing Record 7 of Set 13 | a
# City not found. Skipping...
# Processing Record 8 of Set 13 | kalabo
# Processing Record 9 of Set 13 | ziarat
# Processing Record 10 of Set 13 | khani
# Processing Record 11 of Set 13 | puerto baquerizo moreno
# Processing Record 12 of Set 13 | poum
# Processing Record 13 of Set 13 | aviles
# Processing Record 14 of Set 13 | bukama
# Processing Record 15 of Set 13 | ales
# Processing Record 16 of Set 13 | rapid valley
# Processing Record 17 of Set 13 | grand gaube
# Processing Record 18 of Set 13 | lata
# Processing Record 19 of Set 13 | ketchikan
# Processing Record 20 of Set 13 | broome
# Processing Record 21 of Set 13 | camabatela
# Processing Record 22 of Set 13 | luwuk
# Processing Record 23 of Set 13 | katyuzhanka
# Processing Record 24 of Set 13 | ulagan
# Processing Record 25 of Set 13 | sveio
# Processing Record 26 of Set 13 | acapulco
# Processing Record 27 of Set 13 | kasongo-lunda
# Processing Record 28 of Set 13 | lewiston
# Processing Record 29 of Set 13 | lanzhou
# Processing Record 30 of Set 13 | los llanos de aridane
# Processing Record 31 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 32 of Set 13 | ishigaki
# Processing Record 33 of Set 13 | mormugao
# Processing Record 34 of Set 13 | saraland
# Processing Record 35 of Set 13 | mattru
# Processing Record 36 of Set 13 | aswan
# Processing Record 37 of Set 13 | viransehir
# Processing Record 38 of Set 13 | jumla
# Processing Record 39 of Set 13 | mokrous
# Processing Record 40 of Set 13 | nioro
# Processing Record 41 of Set 13 | kloulklubed
# Processing Record 42 of Set 13 | rio grande
# Processing Record 43 of Set 13 | guangyuan
# Processing Record 44 of Set 13 | chumikan
# Processing Record 45 of Set 13 | college
# Processing Record 46 of Set 13 | buin
# Processing Record 47 of Set 13 | flinders
# Processing Record 48 of Set 13 | manavgat
# Processing Record 49 of Set 13 | wahran
# City not found. Skipping...
# Processing Record 50 of Set 13 | ossora
# Processing Record 1 of Set 14 | schio
# Processing Record 2 of Set 14 | denpasar
# Processing Record 3 of Set 14 | vetis
# Processing Record 4 of Set 14 | wulanhaote
# City not found. Skipping...
# Processing Record 5 of Set 14 | karasburg
# Processing Record 6 of Set 14 | hualmay
# Processing Record 7 of Set 14 | axim
# Processing Record 8 of Set 14 | adeje
# Processing Record 9 of Set 14 | fez
# Processing Record 10 of Set 14 | prince rupert
# Processing Record 11 of Set 14 | port-gentil
# Processing Record 12 of Set 14 | saint-paul
# Processing Record 13 of Set 14 | port keats
# Processing Record 14 of Set 14 | sucua
# Processing Record 15 of Set 14 | nizwa
# Processing Record 16 of Set 14 | vila
# Processing Record 17 of Set 14 | bhadasar
# Processing Record 18 of Set 14 | viedma
# Processing Record 19 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 20 of Set 14 | bac lieu
# Processing Record 21 of Set 14 | zhangjiakou
# Processing Record 22 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 14 | juifang
# City not found. Skipping...
# Processing Record 24 of Set 14 | murray bridge
# Processing Record 25 of Set 14 | boa vista
# Processing Record 26 of Set 14 | caxito
# Processing Record 27 of Set 14 | ubala
# Processing Record 28 of Set 14 | eureka
# Processing Record 29 of Set 14 | oistins
# Processing Record 30 of Set 14 | pasighat
# Processing Record 31 of Set 14 | kalas
# Processing Record 32 of Set 14 | pietarsaari
# Processing Record 33 of Set 14 | miyako
# Processing Record 34 of Set 14 | zhanaozen
# Processing Record 35 of Set 14 | temiscaming
# Processing Record 36 of Set 14 | walcz
# Processing Record 37 of Set 14 | alofi
# Processing Record 38 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 39 of Set 14 | payakumbuh
# Processing Record 40 of Set 14 | chicama
# Processing Record 41 of Set 14 | mago
# Processing Record 42 of Set 14 | mitsamiouli
# Processing Record 43 of Set 14 | soe
# Processing Record 44 of Set 14 | umm lajj
# Processing Record 45 of Set 14 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 46 of Set 14 | bafra
# Processing Record 47 of Set 14 | wanning
# Processing Record 48 of Set 14 | yar-sale
# Processing Record 49 of Set 14 | tabas
# Processing Record 50 of Set 14 | baykit
# Processing Record 1 of Set 15 | mullaitivu
# City not found. Skipping...
# Processing Record 2 of Set 15 | gondanglegi
# Processing Record 3 of Set 15 | jackson
# Processing Record 4 of Set 15 | tshikapa
# Processing Record 5 of Set 15 | villaviciosa
# Processing Record 6 of Set 15 | bartica
# Processing Record 7 of Set 15 | santa isabel do rio negro
# Processing Record 8 of Set 15 | fairmont
# Processing Record 9 of Set 15 | husavik
# Processing Record 10 of Set 15 | seoul
# Processing Record 11 of Set 15 | half moon bay
# Processing Record 12 of Set 15 | banska stiavnica
# Processing Record 13 of Set 15 | ajdabiya
# Processing Record 14 of Set 15 | quba
# Processing Record 15 of Set 15 | ornskoldsvik
# Processing Record 16 of Set 15 | abu kamal
# Processing Record 17 of Set 15 | jinchang
# Processing Record 18 of Set 15 | dire
# Processing Record 19 of Set 15 | sungairaya
# Processing Record 20 of Set 15 | port macquarie
# Processing Record 21 of Set 15 | garango
# Processing Record 22 of Set 15 | gimli
# Processing Record 23 of Set 15 | opuwo
# Processing Record 24 of Set 15 | obidos
# Processing Record 25 of Set 15 | benicarlo
# Processing Record 26 of Set 15 | leh
# Processing Record 27 of Set 15 | gavle
# Processing Record 28 of Set 15 | noboribetsu
# Processing Record 29 of Set 15 | khrebtovaya
# Processing Record 30 of Set 15 | harper
# Processing Record 31 of Set 15 | rio gallegos
# Processing Record 32 of Set 15 | robertsport
# Processing Record 33 of Set 15 | alcaniz
# Processing Record 34 of Set 15 | bytow
# Processing Record 35 of Set 15 | kamloops
# Processing Record 36 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 37 of Set 15 | amazar
# Processing Record 38 of Set 15 | erenhot
# Processing Record 39 of Set 15 | ustye
# Processing Record 40 of Set 15 | tiruvottiyur
# City not found. Skipping...
# Processing Record 41 of Set 15 | hamilton
# Processing Record 42 of Set 15 | ithaca
# Processing Record 43 of Set 15 | angoche
# Processing Record 44 of Set 15 | boende
# Processing Record 45 of Set 15 | paramonga
# Processing Record 46 of Set 15 | kidal
# Processing Record 47 of Set 15 | qasigiannguit
# Processing Record 48 of Set 15 | georgiyevka
# Processing Record 49 of Set 15 | makakilo city
# Processing Record 50 of Set 15 | saint-augustin
# Processing Record 1 of Set 16 | benguela
# Processing Record 2 of Set 16 | mascota
# Processing Record 3 of Set 16 | kalmunai
# Processing Record 4 of Set 16 | carikar
# City not found. Skipping...
# Processing Record 5 of Set 16 | bandarbeyla
# Processing Record 6 of Set 16 | elat
# Processing Record 7 of Set 16 | acajutla
# Processing Record 8 of Set 16 | genhe
# Processing Record 9 of Set 16 | tabiauea
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)

##TW Note: make sure to put [0] after ["weather] because it's being retrieved from LIST in jason 'weather': [{'id': 803,xxxx. 
## city_weather_descrpt = city_weather["weather"][0]["description"]
# Out:
# 693

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
## Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Ruidoso  33.3317 -105.6730     54.14        94         100
# 1         Kahului  20.8947 -156.4700     76.84        73           0
# 2          Funtua  11.5233    7.3081     87.87        21          40
# 3          Shingu  33.7333  135.9833     68.86        89         100
# 4            Lebu -37.6167  -73.6500     55.18        78          87
# 5          Aktash  50.3000   87.7333     31.21        43          74
# 6          Albany  42.6001  -73.9662     53.89        68         100
# 7         Rikitea -23.1203 -134.9692     68.58        66          88
# 8      Vila Velha -20.3297  -40.2925     76.95        77          40
# 9  Ribeira Grande  38.5167  -28.7000     70.20        49          20
#
#    Wind Speed Current Description Country
# 0        3.44     overcast clouds      US
# 1        6.91           clear sky      US
# 2        9.55    scattered clouds      NG
# 3        5.14     overcast clouds      JP
# 4       13.06     overcast clouds      CL
# 5        5.35       broken clouds      RU
# 6        1.41     overcast clouds      US
# 7       21.03     overcast clouds      PF
# 8        4.61    scattered clouds      BR
# 9       17.27          few clouds      PT

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description', 'Country'],
#       dtype='object')

# %%
## Create a list to reorder the column names as follows:
## "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]
## Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]
## Display sample data
city_data_df.head(5)
# Out:
#       City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Ruidoso      US  33.3317 -105.6730     54.14        94         100
# 1  Kahului      US  20.8947 -156.4700     76.84        73           0
# 2   Funtua      NG  11.5233    7.3081     87.87        21          40
# 3   Shingu      JP  33.7333  135.9833     68.86        89         100
# 4     Lebu      CL -37.6167  -73.6500     55.18        78          87
#
#    Wind Speed Current Description
# 0        3.44     overcast clouds
# 1        6.91           clear sky
# 2        9.55    scattered clouds
# 3        5.14     overcast clouds
# 4       13.06     overcast clouds

# %%
## Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
## Set the output file name (CSV) - folder name/file name.csv
output_data_file = "Weather_Database/WeatherPy_Database.csv"

## Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
